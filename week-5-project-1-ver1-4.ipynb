# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2A: Get the Data](#step2a)
# - [Step 2B: Explore the Data](#step2b)
# - [Step 2C: Create Sample Data](#step2c)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#predictions)
# - [Step 6. Display Mistakes](#display)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 1: Data Understanding & Pipeline Check</font>
#
# Here, we will slightly modify the steps  we had used to train Neural Networks:
#
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data, and check the pipeline before training the full network
# - Step 5 - Train on full Data
# - Step 6 - Improve your model
#
#
# In this notebook we will detail the steps 1 to 4, and do some coding along the way! You will implement Steps 5 & 6 in the next notebook.
#
# This notebook contains  30 points. <font style="color:red">The sections in red are the ones that carry marks.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your Problem </font><a name="step1"></a>
#
# As you already know, Image Classification helps classify an image based on its visual content. So, the model is supposed to look at the given image and predict which object is present in it. Obviously, the number of objects which it can predict depends on how many you trained it on.
#
#
# In our problem, we want to classify an input image between **3 animals - Cat, Dog and Panda**.
#
# ### <font style="color:green">What Do We Need and How to Achieve It? </font>
#
# You need correctly-labelled images of each animal. Train a decent-sized network to , understand the input image.

# %% [markdown]
# # <font style="color:blue">Step 2A: Get the Data </font><a name="step2a"></a>
#
# Let’s use a dataset from kaggle. [**Check it out here**](https://www.kaggle.com/ashishsaxena2209/animal-image-datasetdog-cat-and-panda).
#
# It has separate folders for each animal, each consisting of `1000` images. We have split it into `80:20` ratio for `train:validation`. To download, [**click  here**](https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1).

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip
# Out:
# --2023-06-08 04:34:58--  https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra [following]
# --2023-06-08 04:34:59--  https://www.dropbox.com/sh/dl/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com/zip_download_get/Bg8A1lfo8OIlAdhLo3OX-VaENqp936qAOpgd7Yk2MHr6uPtXqd9ykJ-p3c0khMmIwq6DPrSEgeGLWxcekXOhS1uuq_jsLL_aHZXtQmtxoPqf9w?dl=1# [following]
# --2023-06-08 04:35:00--  https://ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com/zip_download_get/Bg8A1lfo8OIlAdhLo3OX-VaENqp936qAOpgd7Yk2MHr6uPtXqd9ykJ-p3c0khMmIwq6DPrSEgeGLWxcekXOhS1uuq_jsLL_aHZXtQmtxoPqf9w?dl=1
# Resolving ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com (ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com (ucce4e98194c56926dbeaebce10c.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197683526 (189M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 188.53M  12.4MB/s    in 37s
#
# 2023-06-08 04:35:38 (5.13 MB/s) - ‘data.zip’ saved [197683526/197683526]

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
# !unzip -q data.zip
# Out:
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font style="color:blue">Step 2B: Explore the Data [5 Points]</font><a name="step2b"></a>
#
# Here are  some examples:

# %% [markdown]
# ### <font style="color:green">Folder Structure </font>

# %%
# !tree -d ./cat-dog-panda
# Out:
# ./cat-dog-panda
# ├── training
# │   ├── cat
# │   ├── dog
# │   └── panda
# └── validation
#     ├── cat
#     ├── dog
#     └── panda
#
# 8 directories

# %% [markdown]
# ### <font style="color:green">Import the Datasets Module</font>
#
# Load the data,  using the datasets module, and . , check out its structure .

# %%
from torchvision import datasets

# %% [markdown]
# ### <font style="color:green">Create a Dataset Object </font>

# %%
train_data = datasets.ImageFolder("./cat-dog-panda/training")
validation_data = datasets.ImageFolder("./cat-dog-panda/validation")

# %% [markdown]
# ### <font style="color:green">List the Classes</font>
#
# It simply prints the sub folders present under the training or validation folder.

# %%
print(train_data.classes)
print(validation_data.classes)
# Out:
# ['cat', 'dog', 'panda']
# ['cat', 'dog', 'panda']

# %% [markdown]
# ### <font style="color:green">Get the Class ID to Name Mapping</font>

# %%
print(train_data.class_to_idx)
print(validation_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1, 'panda': 2}
# {'cat': 0, 'dog': 1, 'panda': 2}

# %% [markdown]
# ### <font style="color:red">Find the Number of Samples in Training and Validation Folders [2 Points]</font>

# %%
# Enter Code Here
train_samples = len(train_data)
validation_samples = len(validation_data)
print("Number of training samples:", train_samples)
print("Number of validation samples:", validation_samples)
# Out:
# Number of training samples: 2400
# Number of validation samples: 600

# %% [markdown]
# ### <font style="color:red">Display Some Samples [3 Points]</font>
# Display one sample from each class. We know that the train dataset contains
#
# - cats from 0 to 799
# - dogs from 800 to 1599
# - pandas from 1600 to 2399
#
# Take one sample from each class and display using matplotlib

# %%
# Enter Code Here
import numpy as np
rand_num = np.random.randint(0, 799)
img,target = train_data[rand_num]
print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (399, 315), target: 0

# %%
# Enter Code Here
rand_num = np.random.randint(800, 1599)
img, target = train_data[rand_num]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (455, 471), target: 1

# %%
# Enter Code Here
rand_num = np.random.randint(1600, 2399)
img, target = train_data[rand_num]
print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (500, 375), target: 2

# %% [markdown]
# **Note:** The images are all of different size.

# %% [markdown]
# # <font style="color:blue">Step 2C: Create Sample Data</font><a name="step2c"></a>
#
# Take `5%` images from training and validation to create a small sample dataset, which will check our training pipeline.

# %%
import torch
import numpy as np

# %%
subset_size = .05

# %% [markdown]
# ### <font style="color:green">Create a Subset From the Original Data</font>
#
# Instead of copying the original data, use the `Subset` method in `Torch` to create a subset of the data. And use this to train the model.
#
#
# This is new. Let’ss see how it is done.

# %%
train_subset = torch.utils.data.Subset(train_data,np.arange(0,len(train_data),1./subset_size))
validation_subset = torch.utils.data.Subset(validation_data,np.arange(0,len(validation_data),1./subset_size))

# %%
train_subset_loader = torch.utils.data.DataLoader(train_subset,
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)
validation_subset_loader = torch.utils.data.DataLoader(validation_subset, 
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)

# %%
print("Train Subset Size: {}".format(len(train_subset_loader.dataset)))
print("Validation Subset Size: {}".format(len(validation_subset_loader.dataset)))
# Out:
# Train Subset Size: 120
# Validation Subset Size: 30

# %% [markdown]
# You can see that the subset data is only 5% of the original training and validation data.

# %% [markdown]
# We will create a separate function called `subset_data_loader` to create data loaders for subsets.

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation [5 Points]</font>  <a name="step3"></a>
#
# Now that you have seen how the data is organized, configure the train and test loaders to feed  the training pipeline.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:blue">3.2. Image Transforms</font>
#
# We need to normalize the data. Some of the  standard ways of doing it is to, subtract the mean, make all images equal in size or to rescale the range to \[0,1\] etc. , Use the following functions to do this:

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>
# Normalize for mean and std.
#
# You can add any other transforms here as per your dataset.

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>
# Function for getting mean and variance

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
        
    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
#
# Data loader used by the training routine to  generate batches of data:

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ### <font style="color:green">3.3.2. Data Loader for Subset</font>
# Data loader which uses the `subset` to generate batches

# %%
def subset_data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

    loader = torch.utils.data.DataLoader(data_subset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:red">3.4. Prepare Data [5 Points]</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
       
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = transforms.Compose([
            transforms.Resize(256),
            transforms.ToTensor(),
            transforms.RandomChoice([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip() ]),
            transforms.CenterCrop(224),
            transforms.Normalize(mean,std)
        ])
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    
    train_loader = subset_data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    
    test_data_path = os.path.join(data_root, 'validation')
    
    test_loader = subset_data_loader(test_data_path, 
                              train_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    return train_loader, test_loader

# %% [markdown]
# ### <font style="color:red">Question </font>[5 Points]
#
# There are two mistakes in the above code snippet. Spot the errors and correct them all. (Note: The rest of the code will run, even if you fail to find the mistakes.)

# %% [markdown]
# # <font style="color:blue">Step 4: Train a Simple Model</font><a name="step4"></a>
#
# It is time to create the training pipeline and train a simple model on the sample data. We provide most of the code in this section. In the next notebook,  you  are the one who will have to make all the changes.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [ 5 Points]</font>
#
# In this section, define the training  and system configurations. Also, specify the batch size, data path, learning rate etc.
#
#
# ### <font style="color:red">Question </font>[5 Points]:
#
# Set up the training pipeline with a batch size of `4`. Run the experiment then for `100` epochs. Change the configurations as given below:

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 100  
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You already know the training function. No need to make any changes:

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
):
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
):
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Please note here that before calling the train function, we calculate the validation loss.  It should be close to $log(\text{num_classes})$ and the accuracy should be close to  $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">4.8. Define Model</font>
#
# In the section,  define the CNN model and train the model.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=64*52*52, out_features=1024), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=1024, out_features=3)
            
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x

# %% [markdown]
# ## <font style="color:blue">4.9. Training</font>

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=173056, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=False)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
#
# Test set: Average loss: 1.0955, Accuracy: 10/30 (33%)
#
# Initial Test Loss : 1.095534,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 1.314880 Acc: 0.4583
# Elapsed 2.39s, 2.39 s/epoch, 0.08 s/batch, ets 236.35s
#
# Test set: Average loss: 0.8233, Accuracy: 20/30 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 0.541654 Acc: 0.7833
# Elapsed 6.63s, 3.31 s/epoch, 0.11 s/batch, ets 324.71s
#
# Test set: Average loss: 0.7594, Accuracy: 18/30 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 0.180564 Acc: 0.9500
# Elapsed 11.22s, 3.74 s/epoch, 0.12 s/batch, ets 362.87s
#
# Test set: Average loss: 0.9880, Accuracy: 16/30 (53%)
#
# Epoch: 3
# Train Loss: 0.062141 Acc: 1.0000
# Elapsed 13.04s, 3.26 s/epoch, 0.11 s/batch, ets 312.99s
#
# Test set: Average loss: 0.9865, Accuracy: 16/30 (53%)
#
# Epoch: 4
# Train Loss: 0.025125 Acc: 1.0000
# Elapsed 14.83s, 2.97 s/epoch, 0.10 s/batch, ets 281.80s
#
# Test set: Average loss: 0.8303, Accuracy: 19/30 (63%)
#
# Epoch: 5
# Train Loss: 0.007892 Acc: 1.0000
# Elapsed 16.60s, 2.77 s/epoch, 0.09 s/batch, ets 260.13s
#
# Test set: Average loss: 0.9210, Accuracy: 20/30 (67%)
#
# Epoch: 6
# Train Loss: 0.003672 Acc: 1.0000
# Elapsed 18.37s, 2.62 s/epoch, 0.09 s/batch, ets 244.01s
#
# Test set: Average loss: 0.9185, Accuracy: 20/30 (67%)
#
# Epoch: 7
# Train Loss: 0.002114 Acc: 1.0000
# Elapsed 20.11s, 2.51 s/epoch, 0.08 s/batch, ets 231.32s
#
# Test set: Average loss: 0.9538, Accuracy: 20/30 (67%)
#
# Epoch: 8
# Train Loss: 0.001532 Acc: 1.0000
# Elapsed 21.91s, 2.43 s/epoch, 0.08 s/batch, ets 221.54s
#
# Test set: Average loss: 0.9606, Accuracy: 21/30 (70%)
#
# Epoch: 9
# Train Loss: 0.001171 Acc: 1.0000
# Elapsed 23.79s, 2.38 s/epoch, 0.08 s/batch, ets 214.10s
#
# Test set: Average loss: 1.0152, Accuracy: 20/30 (67%)
#
# Epoch: 10
# Train Loss: 0.000934 Acc: 1.0000
# Elapsed 25.53s, 2.32 s/epoch, 0.08 s/batch, ets 206.57s
#
# Test set: Average loss: 1.0139, Accuracy: 21/30 (70%)
#
# Epoch: 11
# Train Loss: 0.000764 Acc: 1.0000
# Elapsed 27.28s, 2.27 s/epoch, 0.08 s/batch, ets 200.08s
#
# Test set: Average loss: 1.0354, Accuracy: 20/30 (67%)
#
# Epoch: 12
# Train Loss: 0.000632 Acc: 1.0000
# Elapsed 29.03s, 2.23 s/epoch, 0.07 s/batch, ets 194.28s
#
# Test set: Average loss: 1.0511, Accuracy: 20/30 (67%)
#
# Epoch: 13
# Train Loss: 0.000535 Acc: 1.0000
# Elapsed 30.79s, 2.20 s/epoch, 0.07 s/batch, ets 189.14s
#
# Test set: Average loss: 1.0707, Accuracy: 21/30 (70%)
#
# Epoch: 14
# Train Loss: 0.000458 Acc: 1.0000
# Elapsed 32.64s, 2.18 s/epoch, 0.07 s/batch, ets 184.98s
#
# Test set: Average loss: 1.0849, Accuracy: 20/30 (67%)
#
# Epoch: 15
# Train Loss: 0.000397 Acc: 1.0000
# Elapsed 34.74s, 2.17 s/epoch, 0.07 s/batch, ets 182.37s
#
# Test set: Average loss: 1.1021, Accuracy: 20/30 (67%)
#
# Epoch: 16
# Train Loss: 0.000352 Acc: 1.0000
# Elapsed 36.51s, 2.15 s/epoch, 0.07 s/batch, ets 178.26s
#
# Test set: Average loss: 1.1130, Accuracy: 21/30 (70%)
#
# Epoch: 17
# Train Loss: 0.000302 Acc: 1.0000
# Elapsed 38.26s, 2.13 s/epoch, 0.07 s/batch, ets 174.32s
#
# Test set: Average loss: 1.1218, Accuracy: 21/30 (70%)
#
# Epoch: 18
# Train Loss: 0.000265 Acc: 1.0000
# Elapsed 40.02s, 2.11 s/epoch, 0.07 s/batch, ets 170.61s
#
# Test set: Average loss: 1.1432, Accuracy: 21/30 (70%)
#
# Epoch: 19
# Train Loss: 0.000237 Acc: 1.0000
# Elapsed 41.81s, 2.09 s/epoch, 0.07 s/batch, ets 167.22s
#
# Test set: Average loss: 1.1480, Accuracy: 21/30 (70%)
#
# Epoch: 20
# Train Loss: 0.000213 Acc: 1.0000
# Elapsed 43.55s, 2.07 s/epoch, 0.07 s/batch, ets 163.85s
#
# Test set: Average loss: 1.1595, Accuracy: 22/30 (73%)
#
# Epoch: 21
# Train Loss: 0.000189 Acc: 1.0000
# Elapsed 45.39s, 2.06 s/epoch, 0.07 s/batch, ets 160.94s
#
# Test set: Average loss: 1.1796, Accuracy: 21/30 (70%)
#
# Epoch: 22
# Train Loss: 0.000170 Acc: 1.0000
# Elapsed 47.14s, 2.05 s/epoch, 0.07 s/batch, ets 157.82s
#
# Test set: Average loss: 1.1873, Accuracy: 21/30 (70%)
#
# Epoch: 23
# Train Loss: 0.000154 Acc: 1.0000
# Elapsed 48.90s, 2.04 s/epoch, 0.07 s/batch, ets 154.84s
#
# Test set: Average loss: 1.1922, Accuracy: 21/30 (70%)
#
# Epoch: 24
# Train Loss: 0.000139 Acc: 1.0000
# Elapsed 50.66s, 2.03 s/epoch, 0.07 s/batch, ets 151.97s
#
# Test set: Average loss: 1.2033, Accuracy: 21/30 (70%)
#
# Epoch: 25
# Train Loss: 0.000127 Acc: 1.0000
# Elapsed 52.44s, 2.02 s/epoch, 0.07 s/batch, ets 149.26s
#
# Test set: Average loss: 1.2150, Accuracy: 22/30 (73%)
#
# Epoch: 26
# Train Loss: 0.000117 Acc: 1.0000
# Elapsed 54.19s, 2.01 s/epoch, 0.07 s/batch, ets 146.52s
#
# Test set: Average loss: 1.2193, Accuracy: 22/30 (73%)
#
# Epoch: 27
# Train Loss: 0.000106 Acc: 1.0000
# Elapsed 56.02s, 2.00 s/epoch, 0.07 s/batch, ets 144.05s
#
# Test set: Average loss: 1.2429, Accuracy: 21/30 (70%)
#
# Epoch: 28
# Train Loss: 0.000097 Acc: 1.0000
# Elapsed 57.79s, 1.99 s/epoch, 0.07 s/batch, ets 141.50s
#
# Test set: Average loss: 1.2443, Accuracy: 21/30 (70%)
#
# Epoch: 29
# Train Loss: 0.000089 Acc: 1.0000
# Elapsed 59.55s, 1.98 s/epoch, 0.07 s/batch, ets 138.95s
#
# Test set: Average loss: 1.2489, Accuracy: 22/30 (73%)
#
# Epoch: 30
# Train Loss: 0.000082 Acc: 1.0000
# Elapsed 61.37s, 1.98 s/epoch, 0.07 s/batch, ets 136.59s
#
# Test set: Average loss: 1.2612, Accuracy: 21/30 (70%)
#
# Epoch: 31
# Train Loss: 0.000076 Acc: 1.0000
# Elapsed 63.13s, 1.97 s/epoch, 0.07 s/batch, ets 134.16s
#
# Test set: Average loss: 1.2628, Accuracy: 22/30 (73%)
#
# Epoch: 32
# Train Loss: 0.000071 Acc: 1.0000
# Elapsed 64.91s, 1.97 s/epoch, 0.07 s/batch, ets 131.80s
#
# Test set: Average loss: 1.2724, Accuracy: 22/30 (73%)
#
# Epoch: 33
# Train Loss: 0.000066 Acc: 1.0000
# Elapsed 67.08s, 1.97 s/epoch, 0.07 s/batch, ets 130.22s
#
# Test set: Average loss: 1.2835, Accuracy: 22/30 (73%)
#
# Epoch: 34
# Train Loss: 0.000061 Acc: 1.0000
# Elapsed 68.84s, 1.97 s/epoch, 0.07 s/batch, ets 127.84s
#
# Test set: Average loss: 1.2850, Accuracy: 22/30 (73%)
#
# Epoch: 35
# Train Loss: 0.000059 Acc: 1.0000
# Elapsed 70.60s, 1.96 s/epoch, 0.07 s/batch, ets 125.50s
#
# Test set: Average loss: 1.2957, Accuracy: 22/30 (73%)
#
# Epoch: 36
# Train Loss: 0.000054 Acc: 1.0000
# Elapsed 72.43s, 1.96 s/epoch, 0.07 s/batch, ets 123.33s
#
# Test set: Average loss: 1.2997, Accuracy: 22/30 (73%)
#
# Epoch: 37
# Train Loss: 0.000051 Acc: 1.0000
# Elapsed 74.22s, 1.95 s/epoch, 0.07 s/batch, ets 121.10s
#
# Test set: Average loss: 1.3023, Accuracy: 22/30 (73%)
#
# Epoch: 38
# Train Loss: 0.000047 Acc: 1.0000
# Elapsed 76.01s, 1.95 s/epoch, 0.06 s/batch, ets 118.89s
#
# Test set: Average loss: 1.3206, Accuracy: 22/30 (73%)
#
# Epoch: 39
# Train Loss: 0.000044 Acc: 1.0000
# Elapsed 77.82s, 1.95 s/epoch, 0.06 s/batch, ets 116.73s
#
# Test set: Average loss: 1.3169, Accuracy: 22/30 (73%)
#
# Epoch: 40
# Train Loss: 0.000042 Acc: 1.0000
# Elapsed 79.58s, 1.94 s/epoch, 0.06 s/batch, ets 114.52s
#
# Test set: Average loss: 1.3212, Accuracy: 22/30 (73%)
#
# Epoch: 41
# Train Loss: 0.000039 Acc: 1.0000
# Elapsed 81.38s, 1.94 s/epoch, 0.06 s/batch, ets 112.39s
#
# Test set: Average loss: 1.3275, Accuracy: 22/30 (73%)
#
# Epoch: 42
# Train Loss: 0.000037 Acc: 1.0000
# Elapsed 83.14s, 1.93 s/epoch, 0.06 s/batch, ets 110.21s
#
# Test set: Average loss: 1.3378, Accuracy: 22/30 (73%)
#
# Epoch: 43
# Train Loss: 0.000035 Acc: 1.0000
# Elapsed 84.91s, 1.93 s/epoch, 0.06 s/batch, ets 108.07s
#
# Test set: Average loss: 1.3372, Accuracy: 22/30 (73%)
#
# Epoch: 44
# Train Loss: 0.000033 Acc: 1.0000
# Elapsed 86.66s, 1.93 s/epoch, 0.06 s/batch, ets 105.92s
#
# Test set: Average loss: 1.3483, Accuracy: 22/30 (73%)
#
# Epoch: 45
# Train Loss: 0.000031 Acc: 1.0000
# Elapsed 88.50s, 1.92 s/epoch, 0.06 s/batch, ets 103.89s
#
# Test set: Average loss: 1.3503, Accuracy: 22/30 (73%)
#
# Epoch: 46
# Train Loss: 0.000030 Acc: 1.0000
# Elapsed 90.26s, 1.92 s/epoch, 0.06 s/batch, ets 101.78s
#
# Test set: Average loss: 1.3530, Accuracy: 22/30 (73%)
#
# Epoch: 47
# Train Loss: 0.000028 Acc: 1.0000
# Elapsed 92.08s, 1.92 s/epoch, 0.06 s/batch, ets 99.75s
#
# Test set: Average loss: 1.3628, Accuracy: 21/30 (70%)
#
# Epoch: 48
# Train Loss: 0.000027 Acc: 1.0000
# Elapsed 93.84s, 1.92 s/epoch, 0.06 s/batch, ets 97.67s
#
# Test set: Average loss: 1.3606, Accuracy: 22/30 (73%)
#
# Epoch: 49
# Train Loss: 0.000026 Acc: 1.0000
# Elapsed 95.63s, 1.91 s/epoch, 0.06 s/batch, ets 95.63s
#
# Test set: Average loss: 1.3688, Accuracy: 21/30 (70%)
#
# Epoch: 50
# Train Loss: 0.000024 Acc: 1.0000
# Elapsed 97.43s, 1.91 s/epoch, 0.06 s/batch, ets 93.61s
#
# Test set: Average loss: 1.3736, Accuracy: 22/30 (73%)
#
# Epoch: 51
# Train Loss: 0.000023 Acc: 1.0000
# Elapsed 99.59s, 1.92 s/epoch, 0.06 s/batch, ets 91.93s
#
# Test set: Average loss: 1.3753, Accuracy: 22/30 (73%)
#
# Epoch: 52
# Train Loss: 0.000022 Acc: 1.0000
# Elapsed 101.37s, 1.91 s/epoch, 0.06 s/batch, ets 89.90s
#
# Test set: Average loss: 1.3803, Accuracy: 22/30 (73%)
#
# Epoch: 53
# Train Loss: 0.000021 Acc: 1.0000
# Elapsed 103.12s, 1.91 s/epoch, 0.06 s/batch, ets 87.84s
#
# Test set: Average loss: 1.3874, Accuracy: 21/30 (70%)
#
# Epoch: 54
# Train Loss: 0.000020 Acc: 1.0000
# Elapsed 104.88s, 1.91 s/epoch, 0.06 s/batch, ets 85.81s
#
# Test set: Average loss: 1.3885, Accuracy: 22/30 (73%)
#
# Epoch: 55
# Train Loss: 0.000019 Acc: 1.0000
# Elapsed 106.69s, 1.91 s/epoch, 0.06 s/batch, ets 83.83s
#
# Test set: Average loss: 1.3883, Accuracy: 22/30 (73%)
#
# Epoch: 56
# Train Loss: 0.000018 Acc: 1.0000
# Elapsed 108.45s, 1.90 s/epoch, 0.06 s/batch, ets 81.82s
#
# Test set: Average loss: 1.4014, Accuracy: 22/30 (73%)
#
# Epoch: 57
# Train Loss: 0.000017 Acc: 1.0000
# Elapsed 110.24s, 1.90 s/epoch, 0.06 s/batch, ets 79.83s
#
# Test set: Average loss: 1.4061, Accuracy: 21/30 (70%)
#
# Epoch: 58
# Train Loss: 0.000017 Acc: 1.0000
# Elapsed 112.05s, 1.90 s/epoch, 0.06 s/batch, ets 77.86s
#
# Test set: Average loss: 1.4055, Accuracy: 22/30 (73%)
#
# Epoch: 59
# Train Loss: 0.000016 Acc: 1.0000
# Elapsed 113.80s, 1.90 s/epoch, 0.06 s/batch, ets 75.86s
#
# Test set: Average loss: 1.4134, Accuracy: 22/30 (73%)
#
# Epoch: 60
# Train Loss: 0.000015 Acc: 1.0000
# Elapsed 115.55s, 1.89 s/epoch, 0.06 s/batch, ets 73.88s
#
# Test set: Average loss: 1.4122, Accuracy: 22/30 (73%)
#
# Epoch: 61
# Train Loss: 0.000015 Acc: 1.0000
# Elapsed 117.31s, 1.89 s/epoch, 0.06 s/batch, ets 71.90s
#
# Test set: Average loss: 1.4223, Accuracy: 21/30 (70%)
#
# Epoch: 62
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 119.07s, 1.89 s/epoch, 0.06 s/batch, ets 69.93s
#
# Test set: Average loss: 1.4225, Accuracy: 22/30 (73%)
#
# Epoch: 63
# Train Loss: 0.000014 Acc: 1.0000
# Elapsed 120.84s, 1.89 s/epoch, 0.06 s/batch, ets 67.97s
#
# Test set: Average loss: 1.4244, Accuracy: 21/30 (70%)
#
# Epoch: 64
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 122.79s, 1.89 s/epoch, 0.06 s/batch, ets 66.12s
#
# Test set: Average loss: 1.4342, Accuracy: 21/30 (70%)
#
# Epoch: 65
# Train Loss: 0.000013 Acc: 1.0000
# Elapsed 124.56s, 1.89 s/epoch, 0.06 s/batch, ets 64.17s
#
# Test set: Average loss: 1.4330, Accuracy: 22/30 (73%)
#
# Epoch: 66
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 126.32s, 1.89 s/epoch, 0.06 s/batch, ets 62.22s
#
# Test set: Average loss: 1.4424, Accuracy: 21/30 (70%)
#
# Epoch: 67
# Train Loss: 0.000012 Acc: 1.0000
# Elapsed 128.09s, 1.88 s/epoch, 0.06 s/batch, ets 60.28s
#
# Test set: Average loss: 1.4409, Accuracy: 21/30 (70%)
#
# Epoch: 68
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 130.01s, 1.88 s/epoch, 0.06 s/batch, ets 58.41s
#
# Test set: Average loss: 1.4508, Accuracy: 21/30 (70%)
#
# Epoch: 69
# Train Loss: 0.000011 Acc: 1.0000
# Elapsed 132.06s, 1.89 s/epoch, 0.06 s/batch, ets 56.60s
#
# Test set: Average loss: 1.4471, Accuracy: 22/30 (73%)
#
# Epoch: 70
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 133.86s, 1.89 s/epoch, 0.06 s/batch, ets 54.67s
#
# Test set: Average loss: 1.4538, Accuracy: 21/30 (70%)
#
# Epoch: 71
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 135.65s, 1.88 s/epoch, 0.06 s/batch, ets 52.75s
#
# Test set: Average loss: 1.4620, Accuracy: 21/30 (70%)
#
# Epoch: 72
# Train Loss: 0.000010 Acc: 1.0000
# Elapsed 137.44s, 1.88 s/epoch, 0.06 s/batch, ets 50.83s
#
# Test set: Average loss: 1.4632, Accuracy: 21/30 (70%)
#
# Epoch: 73
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 139.21s, 1.88 s/epoch, 0.06 s/batch, ets 48.91s
#
# Test set: Average loss: 1.4650, Accuracy: 21/30 (70%)
#
# Epoch: 74
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 140.99s, 1.88 s/epoch, 0.06 s/batch, ets 47.00s
#
# Test set: Average loss: 1.4719, Accuracy: 21/30 (70%)
#
# Epoch: 75
# Train Loss: 0.000009 Acc: 1.0000
# Elapsed 142.76s, 1.88 s/epoch, 0.06 s/batch, ets 45.08s
#
# Test set: Average loss: 1.4738, Accuracy: 21/30 (70%)
#
# Epoch: 76
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 144.62s, 1.88 s/epoch, 0.06 s/batch, ets 43.20s
#
# Test set: Average loss: 1.4784, Accuracy: 21/30 (70%)
#
# Epoch: 77
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 146.40s, 1.88 s/epoch, 0.06 s/batch, ets 41.29s
#
# Test set: Average loss: 1.4815, Accuracy: 21/30 (70%)
#
# Epoch: 78
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 148.16s, 1.88 s/epoch, 0.06 s/batch, ets 39.38s
#
# Test set: Average loss: 1.4795, Accuracy: 21/30 (70%)
#
# Epoch: 79
# Train Loss: 0.000008 Acc: 1.0000
# Elapsed 149.93s, 1.87 s/epoch, 0.06 s/batch, ets 37.48s
#
# Test set: Average loss: 1.4930, Accuracy: 21/30 (70%)
#
# Epoch: 80
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 151.75s, 1.87 s/epoch, 0.06 s/batch, ets 35.60s
#
# Test set: Average loss: 1.4950, Accuracy: 21/30 (70%)
#
# Epoch: 81
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 153.53s, 1.87 s/epoch, 0.06 s/batch, ets 33.70s
#
# Test set: Average loss: 1.4910, Accuracy: 21/30 (70%)
#
# Epoch: 82
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 155.35s, 1.87 s/epoch, 0.06 s/batch, ets 31.82s
#
# Test set: Average loss: 1.4965, Accuracy: 21/30 (70%)
#
# Epoch: 83
# Train Loss: 0.000007 Acc: 1.0000
# Elapsed 157.12s, 1.87 s/epoch, 0.06 s/batch, ets 29.93s
#
# Test set: Average loss: 1.5001, Accuracy: 21/30 (70%)
#
# Epoch: 84
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 158.90s, 1.87 s/epoch, 0.06 s/batch, ets 28.04s
#
# Test set: Average loss: 1.5071, Accuracy: 21/30 (70%)
#
# Epoch: 85
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 160.66s, 1.87 s/epoch, 0.06 s/batch, ets 26.15s
#
# Test set: Average loss: 1.5068, Accuracy: 21/30 (70%)
#
# Epoch: 86
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 162.82s, 1.87 s/epoch, 0.06 s/batch, ets 24.33s
#
# Test set: Average loss: 1.5130, Accuracy: 21/30 (70%)
#
# Epoch: 87
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 164.58s, 1.87 s/epoch, 0.06 s/batch, ets 22.44s
#
# Test set: Average loss: 1.5125, Accuracy: 21/30 (70%)
#
# Epoch: 88
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 166.41s, 1.87 s/epoch, 0.06 s/batch, ets 20.57s
#
# Test set: Average loss: 1.5195, Accuracy: 21/30 (70%)
#
# Epoch: 89
# Train Loss: 0.000006 Acc: 1.0000
# Elapsed 168.21s, 1.87 s/epoch, 0.06 s/batch, ets 18.69s
#
# Test set: Average loss: 1.5189, Accuracy: 21/30 (70%)
#
# Epoch: 90
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 169.98s, 1.87 s/epoch, 0.06 s/batch, ets 16.81s
#
# Test set: Average loss: 1.5196, Accuracy: 21/30 (70%)
#
# Epoch: 91
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 171.78s, 1.87 s/epoch, 0.06 s/batch, ets 14.94s
#
# Test set: Average loss: 1.5277, Accuracy: 21/30 (70%)
#
# Epoch: 92
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 173.55s, 1.87 s/epoch, 0.06 s/batch, ets 13.06s
#
# Test set: Average loss: 1.5294, Accuracy: 21/30 (70%)
#
# Epoch: 93
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 175.30s, 1.86 s/epoch, 0.06 s/batch, ets 11.19s
#
# Test set: Average loss: 1.5345, Accuracy: 21/30 (70%)
#
# Epoch: 94
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 177.11s, 1.86 s/epoch, 0.06 s/batch, ets 9.32s
#
# Test set: Average loss: 1.5417, Accuracy: 21/30 (70%)
#
# Epoch: 95
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 178.87s, 1.86 s/epoch, 0.06 s/batch, ets 7.45s
#
# Test set: Average loss: 1.5428, Accuracy: 21/30 (70%)
#
# Epoch: 96
# Train Loss: 0.000005 Acc: 1.0000
# Elapsed 180.64s, 1.86 s/epoch, 0.06 s/batch, ets 5.59s
#
# Test set: Average loss: 1.5392, Accuracy: 21/30 (70%)
#
# Epoch: 97
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 182.48s, 1.86 s/epoch, 0.06 s/batch, ets 3.72s
#
# Test set: Average loss: 1.5468, Accuracy: 21/30 (70%)
#
# Epoch: 98
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 184.27s, 1.86 s/epoch, 0.06 s/batch, ets 1.86s
#
# Test set: Average loss: 1.5484, Accuracy: 21/30 (70%)
#
# Epoch: 99
# Train Loss: 0.000004 Acc: 1.0000
# Elapsed 186.05s, 1.86 s/epoch, 0.06 s/batch, ets 0.00s
#
# Test set: Average loss: 1.5537, Accuracy: 21/30 (70%)
#
# Total time: 186.32, Best Loss: 0.759

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5: Sample Prediction</font><a name="predictions"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def calc_prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = calc_prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    print(len(imgs))
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
# 15

# %% [markdown]
# Ddespite training the network on a very small subset of data, you can see that the predictions are not that bad. This means that our model is ready for training.

# %% [markdown]
# # <font style="color:red">Step 6. Display Mistakes [15 points] </font><a name="display"></a>
#
# The above code displayed sample predictions. But correct predictions are of no use. So, write a similar function that will  display only the mistakes made by the network.
#
#
# **You have to display only 15 images.**

# %%
from torchvision import transforms

train_config = TrainingConfiguration()

batch_size = 16

if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"


#transformations
common_transforms = image_common_transforms(mean,std)

#creating datasets
test_data = datasets.ImageFolder(test_data_path, image_preprocess_transforms())
test_transform_data = datasets.ImageFolder(test_data_path, common_transforms)


#creating dataloaders
test_loader = torch.utils.data.DataLoader(dataset= test_data, 
                         batch_size = batch_size,
                         shuffle = False)
test_trans_loader = torch.utils.data.DataLoader(dataset= test_transform_data, 
                         batch_size = batch_size,
                         shuffle = False)


#Send model to the device and set in evaluation mode
m.to(device)
m.eval()



incorrect_list=[]
for (imgs,_),(x,y) in zip(test_loader, test_trans_loader):
         
    predictions, probability = calc_prediction(m, device, x)
    
    #Finding out the incorrect predictions and selecting those predictions
    y = y.numpy()
    imgs = imgs[y!=predictions]
    probability = probability[y!=predictions]
    predictions= predictions[y!=predictions]
        
    #writing the incorrect predicted image, probabiltity and its predicted class in the dictionary
    for i in range(len(predictions)):
        incorrect_pred_dict={
                    'img' : transforms.functional.to_pil_image(imgs[i]),
                    'pred_class': test_data.classes[predictions[i]],
                    'pred_prob': f"{probability[i]:.2f}"
        }
        incorrect_list.append(incorrect_pred_dict)

        
        
        
#displaying 15 incorrect predictions out of incorrect_list
random_15_pred = np.random.choice(incorrect_list, 15, replace = False)
for i in range(len(random_15_pred)):
    plt.subplot(5,3,i+1)
    plt.imshow(random_15_pred[i]['img'])
    plt.title(f"pred_class: {random_15_pred[i]['pred_class']}, prob: {random_15_pred[i]['pred_prob']}")
    plt.axis('off')

plt.show()

# %% [markdown]
# After completing the assignment, <font style="color:red">upload and submit the notebook on the portal</font> for checking and feedback.
